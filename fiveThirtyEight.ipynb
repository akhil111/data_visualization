# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('http://www.randalolson.com/wp-content/uploads/percent-bachelors-degrees-women-usa.csv')

# %%
df.shape
# Out:
# (42, 18)

# %%
df.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
# this works for only numerical columns
df.describe()
# Out:
#               Year  Agriculture  Architecture  Art and Performance    Biology  \
# count    42.000000    42.000000     42.000000            42.000000  42.000000
# mean   1990.500000    33.848165     33.685540            61.100000  49.429864
# std      12.267844    12.552731      9.574057             1.305336  10.087725
# min    1970.000000     4.229798     11.921005            58.600000  29.088363
# 25%    1980.250000    30.840814     28.520709            60.200000  44.311821
# 50%    1990.500000    33.317552     35.994852            61.300000  50.971469
# 75%    2000.750000    45.663953     40.790605            62.000000  58.679194
# max    2011.000000    50.037182     44.499331            63.400000  62.169456
#
#         Business  Communications and Journalism  Computer Science  Education  \
# count  42.000000                      42.000000         42.000000  42.000000
# mean   40.653471                      56.216667         25.809524  76.356236
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 18 columns):
# Year                             42 non-null int64
# Agriculture                      42 non-null float64
# Architecture                     42 non-null float64
# Art and Performance              42 non-null float64
# Biology                          42 non-null float64
# Business                         42 non-null float64
# Communications and Journalism    42 non-null float64
# Computer Science                 42 non-null float64
# Education                        42 non-null float64
# Engineering                      42 non-null float64
# English                          42 non-null float64
# Foreign Languages                42 non-null float64
# Health Professions               42 non-null float64
# Math and Statistics              42 non-null float64
# Physical Sciences                42 non-null float64
# Psychology                       42 non-null float64
# ...

# %%
#checking for categorical values
df.dtypes[df.dtypes=="object"].index
# Out:
# Index([], dtype='object')

# %%
df.dtypes[df.dtypes=="float"].index
# Out:
# Index(['Agriculture', 'Architecture', 'Art and Performance', 'Biology',
#        'Business', 'Communications and Journalism', 'Computer Science',
#        'Education', 'Engineering', 'English', 'Foreign Languages',
#        'Health Professions', 'Math and Statistics', 'Physical Sciences',
#        'Psychology', 'Public Administration', 'Social Sciences and History'],
#       dtype='object')

# %% [markdown]
# # finding missing values

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Year, Agriculture, Architecture, Art and Performance, Biology, Business, Communications and Journalism, Computer Science, Education, Engineering, English, Foreign Languages, Health Professions, Math and Statistics, Physical Sciences, Psychology, Public Administration, Social Sciences and History]
# Index: []

# %%
#another way of finding values
df.isnull().sum()
# Out:
# Year                             0
# Agriculture                      0
# Architecture                     0
# Art and Performance              0
# Biology                          0
# Business                         0
# Communications and Journalism    0
# Computer Science                 0
# Education                        0
# Engineering                      0
# English                          0
# Foreign Languages                0
# Health Professions               0
# Math and Statistics              0
# Physical Sciences                0
# Psychology                       0
# Public Administration            0
# Social Sciences and History      0
# dtype: int64

# %% [markdown]
#  # Visualization each features

# %%
for i in df.columns.tolist():
    plt.hist(df[i])
    plt.title(i)
    plt.show()

# %%
under_20 = df.loc[0, df.loc[0] < 20]
under_20
# Out:
# Agriculture           4.229798
# Architecture         11.921005
# Business              9.064439
# Computer Science     13.600000
# Engineering           0.800000
# Physical Sciences    13.800000
# Name: 0, dtype: float64

# %%
under_20_graph = df.plot(x = 'Year', y = under_20.index, figsize = (12,8))

# %%
from matplotlib import style
style.available
# Out:
# ['seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-ticks',
#  'fivethirtyeight',
#  'seaborn-whitegrid',
#  'classic',
#  '_classic_test',
#  'seaborn-talk',
#  'seaborn-dark-palette',
#  'seaborn-bright',
#  'seaborn-pastel',
#  'grayscale',
#  'seaborn-notebook',
#  'ggplot',
#  'seaborn-colorblind',
#  'seaborn-muted',
#  'seaborn',
#  'seaborn-paper',
#  'bmh',
#  'seaborn-white',
#  'dark_background',
#  'seaborn-poster',
#  'seaborn-deep']

# %%
style.use('fivethirtyeight')
fte_graph=df.plot(x = 'Year', y = under_20.index, figsize = (12,8),legend=False)

fte_graph.text(x = 1994, y = 44, s = 'Agriculture', weight = 'bold', rotation = 33,
              backgroundcolor = '#f0f0f0')
fte_graph.text(x = 1985, y = 42.2, s = 'Architecture',  weight = 'bold', rotation = 18,
              backgroundcolor = '#f0f0f0')
fte_graph.text(x = 2004, y = 51, s = 'Business',  weight = 'bold', rotation = -5, 
               backgroundcolor = '#f0f0f0')
fte_graph.text(x = 2001, y = 30, s = 'Computer Science',  weight = 'bold', rotation = -42.5,
              backgroundcolor = '#f0f0f0')
fte_graph.text(x = 1987, y = 11.5, s = 'Engineering', weight = 'bold',
              backgroundcolor = '#f0f0f0')
fte_graph.text(x = 1976, y = 25, s = 'Physical Sciences', weight = 'bold', rotation = 27,
              backgroundcolor = '#f0f0f0')

# %% [markdown]
#  # popular Industries by year

# %%
years=df['Year'].tolist()

# %%
columns=df.columns.tolist()

# %%
rows_list=df[columns[1:]].values.tolist()

# %%
for i in np.arange(1,19):
    plt.plot(years,df[columns[i]])
    plt.title(columns[i])
    #plt.plot(years,df['Agriculture'])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-201-02fd7008bc8d> in <module>()
#       1 for i in np.arange(1,19):
# ----> 2     plt.plot(years,df[columns[i]])
#       3     plt.title(columns[i])
#       4     #plt.plot(years,df['Agriculture'])
#       5     plt.show()
#
# IndexError: list index out of range

# %%
israel=[]
for i in np.arange(1,18):
    x=np.sum(df[columns[i]].values.tolist())
    israel.append(x)
    print(x)

# %% [markdown]
# # with matplotlib

# %%
plt.figure(figsize=(10,6))
plt.bar(np.arange(0,17),np.sort(israel).tolist())
#sns.barplot(np.arange(0,17),np.sort(israel).tolist())
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.bar(np.arange(0,17),np.sort(israel).tolist()[::-1])
plt.show()

# %% [markdown]
# # with seaborn

# %%
plt.figure(figsize=(10,6))
sns.barplot(np.arange(0,17),israel)
plt.xticks(np.arange(17),columns[1:],rotation=90)
plt.title("POPULAR DEGREES AMONG  WOMEN SINCE 1971")
plt.show()

# %%
style.use('fivethirtyeight')
fte_graph=df.plot(x = 'Year', y = df.columns.tolist()[1:18], figsize = (20,10),legend=True)
plt.title('PERCENTAGE OF BACHELORS CONFERRED TO WOMEN FROM 1970 TO 2011 IN THE US')
